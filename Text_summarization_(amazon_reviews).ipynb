# %%
import numpy as np
import pandas as pd
import re
from bs4 import BeautifulSoup
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")

# %%
dataset=pd.read_csv("/content/drive/MyDrive/Reviews.csv.zip",nrows=100000)

# %%
dataset.drop_duplicates(subset=['Text'],inplace=True)
dataset.dropna(axis=0,inplace=True)

# %%
contrac_words = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                "you're": "you are", "you've": "you have"}

# %%
import nltk
nltk.download('stopwords')
# Remove stopwords
stop_words = set(stopwords.words('english'))
def cleaner_txt(txt,num):
    string = txt.lower() # convert into lowercase
    string = BeautifulSoup(string, "lxml").text # remove HTML tags
    string = re.sub('"','', string)
    string = ' '.join([contrac_words[t] if t in contrac_words else t for t in string.split(" ")]) # contraction mapping
    string = re.sub(r"'s\b","",string) # remove 's
    string = re.sub("[^a-zA-Z]", " ", string)# Remove any text inside the parenthesis
    string = re.sub('[m]{2,}', 'mm', string)
    if(num==0):
        tokens = [w for w in string.split() if not w in stop_words]
    else:
        tokens=string.split()
    long_words=[]
    for i in tokens:
        if len(i)>1:
            long_words.append(i)
    return (" ".join(long_words)).strip()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#call the function
txt_cleaned = []
for t in dataset['Text']:
    txt_cleaned.append(cleaner_txt(t,0))
summary_cleaned = []
for t in dataset['Summary']:
    summary_cleaned.append(cleaner_txt(t,1))

# %%
dataset['txt_cleaned']=txt_cleaned
dataset['summary_cleaned']=summary_cleaned
#Drop empty rows
dataset.replace('', np.nan, inplace=True)
dataset.dropna(axis=0,inplace=True)

# %%
import matplotlib.pyplot as plt
word_count_text = []
word_count_summary = []
# populate the lists with sentence lengths
for i in dataset['txt_cleaned']:
      word_count_text.append(len(i.split()))

for i in dataset['summary_cleaned']:
      word_count_summary.append(len(i.split()))

len_dataframe = pd.DataFrame({'txt':word_count_text, 'summary':word_count_summary})
len_dataframe.hist(bins = 30)
plt.show()

# %%
count=0
for i in dataset['summary_cleaned']:
    if(len(i.split())<=8):
        count=count+1
print(count/len(dataset['summary_cleaned']))
# Out:
# 0.9411218761318363

# %%
max_len_txt=30
max_len_summary=8

# select the reviews and summaries whose length falls below or equal to **max_len_txt** and **max_len_summary**
txt_cleaned =np.array(dataset['txt_cleaned'])
summary_cleaned=np.array(dataset['summary_cleaned'])

txt_short=[]
summary_short=[]
for i in range(len(txt_cleaned)):
    if(len(summary_cleaned[i].split())<=max_len_summary and len(txt_cleaned[i].split())<=max_len_txt):
        txt_short.append(txt_cleaned[i])
        summary_short.append(summary_cleaned[i])

dataframe=pd.DataFrame({'txt':txt_short,'summary':summary_short})

# add the **START** and **END** special tokens at the beginning and end of the summary.
dataframe['summary'] = dataframe['summary'].apply(lambda x : 'sostok '+ x + ' eostok')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(np.array(dataframe['txt']),np.array(dataframe['summary']),test_size=0.1,random_state=0)

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

# tokenizer for training dataset
tokenizer_x = Tokenizer()
tokenizer_x.fit_on_texts(list(x_train))

# %%
threshold=4
count=0
count_total=0
frequancy=0
frequancy_total=0
for k,v in tokenizer_x.word_counts.items():
    count_total=count_total+1
    frequancy_total=frequancy_total+v

# %%
tokenizer_x = Tokenizer(num_words=count_total-count)
tokenizer_x.fit_on_texts(list(x_train))

#convert text sequences into integer sequences
x_tr_seq    =   tokenizer_x.texts_to_sequences(x_train)
x_val_seq   =   tokenizer_x.texts_to_sequences(x_test)

#padding zero to maximum length
x_train    =   pad_sequences(x_tr_seq,  maxlen=max_len_txt, padding='post')
x_test   =   pad_sequences(x_val_seq, maxlen=max_len_txt, padding='post')

#size of vocabulary ( +1 for padding token)
x_voc   =  tokenizer_x.num_words + 1

# %%
tokenizer_y = Tokenizer()
tokenizer_y.fit_on_texts(list(y_train))

# %%
threshold=6
count=0
count_total=0
frequancy=0
frequancy_total=0
for k,v in tokenizer_y.word_counts.items():
    count_total=count_total+1
    frequancy_total=frequancy_total+v

# %%
tokenizer_y = Tokenizer(num_words=count_total-count)
tokenizer_y.fit_on_texts(list(y_train))

#convert text to integer
y_train_seq    =   tokenizer_y.texts_to_sequences(y_train)
y_test_seq   =   tokenizer_y.texts_to_sequences(y_test)

# padding zero to maximum
y_train    =   pad_sequences(y_train_seq, maxlen=max_len_summary, padding='post')
y_test   =   pad_sequences(y_test_seq, maxlen=max_len_summary, padding='post')

# size of vocabulary
y_vocab  =   tokenizer_y.num_words +1

# %%
tokenizer_y.word_counts['sostok'],len(y_train)
# Out:
# (41738, 41738)

# %%
index=[]
for i in range(len(y_train)):
    count=0
    for j in y_train[i]:
        if j!=0:
            count=count+1
    if(count==2):
        index.append(i)
y_train=np.delete(y_train,index, axis=0)
x_train=np.delete(x_train,index, axis=0)

# %%
index=[]
for i in range(len(y_test)):
    count=0
    for j in y_test[i]:
        if j!=0:
            count=count+1
    if(count==2):
        index.append(i)
y_test=np.delete(y_test,index, axis=0)
x_test=np.delete(x_test,index, axis=0)

# %%
import tensorflow as tf
from tensorflow.python.keras import backend as K

logger = tf.get_logger()

class AttentionLayer(tf.keras.layers.Layer):
    """
    This class implements Bahdanau attention (https://arxiv.org/pdf/1409.0473.pdf).
    There are three sets of weights introduced W_a, U_a, and V_a
     """

    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        assert isinstance(input_shape, list)
        # Create a trainable weight variable for this layer.

        self.W_a = self.add_weight(name='W_a',
                                   shape=tf.TensorShape((input_shape[0][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.U_a = self.add_weight(name='U_a',
                                   shape=tf.TensorShape((input_shape[1][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.V_a = self.add_weight(name='V_a',
                                   shape=tf.TensorShape((input_shape[0][2], 1)),
                                   initializer='uniform',
                                   trainable=True)

        super(AttentionLayer, self).build(input_shape)  # Be sure to call this at the end

    def call(self, inputs):
        """
        inputs: [encoder_output_sequence, decoder_output_sequence]
        """
        assert type(inputs) == list
        encoder_out_seq, decoder_out_seq = inputs

        logger.debug(f"encoder_out_seq.shape = {encoder_out_seq.shape}")
        logger.debug(f"decoder_out_seq.shape = {decoder_out_seq.shape}")

        def energy_step(inputs, states):
            """ Step function for computing energy for a single decoder state
            inputs: (batchsize * 1 * de_in_dim)
            states: (batchsize * 1 * de_latent_dim)
            """

            logger.debug("Running energy computation step")

            if not isinstance(states, (list, tuple)):
                raise TypeError(f"States must be an iterable. Got {states} of type {type(states)}")

            encoder_full_seq = states[-1]

            """ Computing S.Wa where S=[s0, s1, ..., si]"""
            # <= batch size * en_seq_len * latent_dim
            W_a_dot_s = K.dot(encoder_full_seq, self.W_a)

            """ Computing hj.Ua """
            U_a_dot_h = K.expand_dims(K.dot(inputs, self.U_a), 1)  # <= batch_size, 1, latent_dim

            logger.debug(f"U_a_dot_h.shape = {U_a_dot_h.shape}")

            """ tanh(S.Wa + hj.Ua) """
            # <= batch_size*en_seq_len, latent_dim
            Ws_plus_Uh = K.tanh(W_a_dot_s + U_a_dot_h)

            logger.debug(f"Ws_plus_Uh.shape = {Ws_plus_Uh.shape}")

            """ softmax(va.tanh(S.Wa + hj.Ua)) """
            # <= batch_size, en_seq_len
            e_i = K.squeeze(K.dot(Ws_plus_Uh, self.V_a), axis=-1)
            # <= batch_size, en_seq_len
            e_i = K.softmax(e_i)

            logger.debug(f"ei.shape = {e_i.shape}")

            return e_i, [e_i]

        def context_step(inputs, states):
            """ Step function for computing ci using ei """

            logger.debug("Running attention vector computation step")

            if not isinstance(states, (list, tuple)):
                raise TypeError(f"States must be an iterable. Got {states} of type {type(states)}")

            encoder_full_seq = states[-1]

            # <= batch_size, hidden_size
            c_i = K.sum(encoder_full_seq * K.expand_dims(inputs, -1), axis=1)

            logger.debug(f"ci.shape = {c_i.shape}")

            return c_i, [c_i]

        # we don't maintain states between steps when computing attention
        # attention is stateless, so we're passing a fake state for RNN step function
        fake_state_c = K.sum(encoder_out_seq, axis=1)
        fake_state_e = K.sum(encoder_out_seq, axis=2)  # <= (batch_size, enc_seq_len, latent_dim

        """ Computing energy outputs """
        # e_outputs => (batch_size, de_seq_len, en_seq_len)
        last_out, e_outputs, _ = K.rnn(
            energy_step, decoder_out_seq, [fake_state_e], constants=[encoder_out_seq]
        )

        """ Computing context vectors """
        last_out, c_outputs, _ = K.rnn(
            context_step, e_outputs, [fake_state_c], constants=[encoder_out_seq]
        )

        return c_outputs, e_outputs

    def compute_output_shape(self, input_shape):
        """ Outputs produced by the layer """
        return [
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[1][2])),
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[0][1]))
        ]

# %%
K.clear_session()
dim_latent = 300
dim_emb=100

# Encoder
en_input = Input(shape=(max_len_txt,))

#embedding layer
en_embedding =  Embedding(x_voc, dim_emb,trainable=True)(en_input)

# lstm 1
en_lstm1 = LSTM(dim_latent,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
en_output1, state_hidden1, state_c1 = en_lstm1(en_embedding)

# lstm 2
en_lstm2 = LSTM(dim_latent,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
en_output2, state_hidden2, state_c2 = en_lstm2(en_output1)

# lstm 3
en_lstm3=LSTM(dim_latent, return_state=True, return_sequences=True,dropout=0.4,recurrent_dropout=0.4)
en_outputs, state_hidden, state_c= en_lstm3(en_output2)

# Set up the decoder
dec_input = Input(shape=(None,))

#embedding layer
emb_layer_dec = Embedding(y_vocab, dim_emb,trainable=True)
dec_embedding = emb_layer_dec(dec_input)

dec_lstm = LSTM(dim_latent, return_sequences=True, return_state=True,dropout=0.4,recurrent_dropout=0.2)
dec_output,dec_fwd_state, dec_back_state = dec_lstm(dec_embedding,initial_state=[state_hidden, state_c])

# Attention layer
attention_layer = AttentionLayer(name='attention_layer')
attention_output, attention_states = attention_layer([en_outputs, dec_output])

# Concatinate attention input and decoder LSTM output
dec_concate_input = Concatenate(axis=-1, name='concat_layer')([dec_output, attention_output])

# Dense layer
dec_dense =  TimeDistributed(Dense(y_vocab, activation='softmax'))
dec_output = dec_dense(dec_concate_input)

# Define the model
model = Model([en_input, dec_input], dec_output)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding (Embedding)       (None, 30, 100)              2469100   ['input_1[0][0]']
#
#  lstm (LSTM)                 [(None, 30, 300),            481200    ['embedding[0][0]']
#                               (None, 300),
#                               (None, 300)]
#
#  input_2 (InputLayer)        [(None, None)]               0         []
#
#  lstm_1 (LSTM)               [(None, 30, 300),            721200    ['lstm[0][0]']
#                               (None, 300),
#                               (None, 300)]
#
#  embedding_1 (Embedding)     (None, None, 100)            898100    ['input_2[0][0]']
#
#  lstm_2 (LSTM)               [(None, 30, 300),            721200    ['lstm_1[0][0]']
#                               (None, 300),
#                               (None, 300)]
#
#  lstm_3 (LSTM)               [(None, None, 300),          481200    ['embedding_1[0][0]',
#                               (None, 300),                           'lstm_2[0][1]',
#                               (None, 300)]                           'lstm_2[0][2]']
#
#  attention_layer (Attention  ((None, None, 300),          180300    ['lstm_2[0][0]',
#  Layer)                       (None, None, 30))                      'lstm_3[0][0]']
#
#  concat_layer (Concatenate)  (None, None, 600)            0         ['lstm_3[0][0]',
#                                                                      'attention_layer[0][0]']
#
#  time_distributed (TimeDist  (None, None, 8981)           5397581   ['concat_layer[0][0]']
#  ributed)
#
# ==================================================================================================
# Total params: 11349881 (43.30 MB)
# Trainable params: 11349881 (43.30 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy',metrics=['acc'])

# %%
earlystopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=2)

# %%
x=model.fit([x_train,y_train[:,:-1]], y_train.reshape(y_train.shape[0],y_train.shape[1], 1)[:,1:] ,epochs=5,callbacks=[earlystopping])
# Out:
# Epoch 1/5
# 1305/1305 [==============================] - ETA: 0s - loss: 3.2407 - acc: 0.5528
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,acc
# 1305/1305 [==============================] - 1122s 852ms/step - loss: 3.2407 - acc: 0.5528
# Epoch 2/5
# 1305/1305 [==============================] - ETA: 0s - loss: 2.9739 - acc: 0.5761
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,acc
# 1305/1305 [==============================] - 1088s 834ms/step - loss: 2.9739 - acc: 0.5761
# Epoch 3/5
# 1305/1305 [==============================] - ETA: 0s - loss: 2.8801 - acc: 0.5830
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,acc
# 1305/1305 [==============================] - 1087s 833ms/step - loss: 2.8801 - acc: 0.5830
# Epoch 4/5
# 1305/1305 [==============================] - ETA: 0s - loss: 2.8019 - acc: 0.5881
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,acc
# 1305/1305 [==============================] - 1073s 822ms/step - loss: 2.8019 - acc: 0.5881
# Epoch 5/5
# 1305/1305 [==============================] - ETA: 0s - loss: 2.7304 - acc: 0.5927
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,acc
# 1305/1305 [==============================] - 1068s 818ms/step - loss: 2.7304 - acc: 0.5927

# %%
from matplotlib import pyplot as plt
plt.plot(x.history['loss'], label='train',color='green')
plt.legend()
plt.show()

# %%
# build the dictionary to convert the index to word for target and source vocabulary
reverce_targat_word_index=tokenizer_y.index_word
reverce_sourse_word_index=tokenizer_x.index_word
targat_word_index=tokenizer_y.word_index

# %%
en_model = Model(inputs=en_input,outputs=[en_outputs, state_hidden, state_c])

# Decoder
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(dim_latent,))
decoder_state_input_c= Input(shape=(dim_latent,))
dec_hid_stat_ip = Input(shape=(max_len_txt,dim_latent))

# Get the embeddings of the decoder sequence
dec_embedding2= emb_layer_dec(dec_input)

dec_output2, state_hidden2, state_c2 = dec_lstm(dec_embedding2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attention_output_inf, attention_states_inf = attention_layer([dec_hid_stat_ip, dec_output2])
dec_inf_con = Concatenate(axis=-1, name='concat')([dec_output2, attention_output_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
dec_output2 = dec_dense(dec_inf_con)

# decoder model
dec_model = Model(
    [dec_input] + [dec_hid_stat_ip,decoder_state_input_h, decoder_state_input_c],
    [dec_output2] + [state_hidden2, state_c2])

# %%
def decode_seq(input_sequence):
    # Encode the input.
    en_out, en_h, en_c = en_model.predict(input_sequence)

    # Generate empty target sequence of length 1.
    targat_seq = np.zeros((1,1))

    # the first word of target sequence with the start word.
    targat_seq[0, 0] = targat_word_index['sostok']

    stop_cond = False
    dec_sent = ''
    while not stop_cond:

        output_tokans, h, c = dec_model.predict([targat_seq] + [en_out, en_h, en_c])


        sample_index_tokan = np.argmax(output_tokans[0, -1, :])
        sample_tokan = reverce_targat_word_index[sample_index_tokan]

        if(sample_tokan!='eostok'):
            dec_sent += ' '+sample_tokan

        # Exit condition
        if (sample_tokan == 'eostok'  or len(dec_sent.split()) >= (max_len_summary-1)):
            stop_cond = True

        # Update the target sequence.
        targat_seq = np.zeros((1,1))
        targat_seq[0, 0] = sample_index_tokan

        # Update internal states
        en_h, en_c = h, c

    return dec_sent

# %%
def sequence2summary(input_sequence):
    string=''
    for i in input_sequence:
        if((i!=0 and i!=targat_word_index['sostok']) and i!=targat_word_index['eostok']):
            string=string+reverce_targat_word_index[i]+' '
    return string

def sequence2text(input_sequence):
    string=''
    for i in input_sequence:
        if(i!=0):
            string=string+reverce_sourse_word_index[i]+' '
    return string

# %%
for i in range(0,100):
    print("Review:",sequence2text(x_train[i]))
    print("Original summary:",sequence2summary(y_train[i]))
    print("Predicted summary:",decode_seq(x_train[i].reshape(1,max_len_txt)))
    print("\n")
# Out:
# Review: skinless sardines water differ ones skin oil somewhat coarse dense opposed softer texture sardines oil much fishy odor liquid flavorful
# Original summary: skinless sardines in water
# 1/1 [==============================] - 1s 887ms/step
# 1/1 [==============================] - 1s 605ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# Predicted summary:  great product
#
#
# Review: give three cats every treat love husband bought whiskas brand purple box cats snub noses hah boy finicky
# Original summary: cats love it
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 57ms/step
# Predicted summary:  great product for dogs
#
#
# Review: comes soft hard brown rice products used sushi rice rice may difficult find buying wonderful
# Original summary: best brown rice ever
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 33ms/step
# Predicted summary:  great tasting
#
#
# Review: love travel year old eats car snack time love hidden veggies calls smoothie
# Original summary: great snack for toddler
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# Predicted summary:  great product
#
#
# Review: expect gum typical lime flavored candy type taste floored gum literally tastes like key lime pie swear even taste graham cracker crust flavor lasts short time amazing taste floored
# Original summary: shocked so amazing
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  great taste
#
#
# Review: christmas year received box sahika turkish delight loved decided wanted get another box share went back home ordered product unfortunately consistency gritty nearly flavorful original sahika brand buying sultans
# Original summary: not as good as other brands
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  great product
#
#
# Review: really like ritter chocolates though sometimes pick local grocery much expensive keep ritter sport rum raisin nut desk work exercise whole lot self control make last
# Original summary: love this stuff
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# Predicted summary:  great product
#
#
# Review: good feeding mechanism dog scarfs food far toy challenges cakewalk great start kyjen start marketing people love nina ottoson want spend one toy definitely try kyjen games see challenging
# Original summary: for smart dogs or large treats kibble
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# Predicted summary:  great product for dogs
#
#
# Review: tried tea tea room recently absolutely divine tea nice balance sweet spicy almost like chai tea even better friend like tea tried absolutely loved definitely great tea
# Original summary: fantastic treat
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# Predicted summary:  great coffee
#
#
# Review: california grew zoom best wheat cereal holds day moved texas could find zoom anywhere say time always find looking amazon searched buying unit pack ever since try disappointed
# Original summary: good stuff
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# Predicted summary:  great tasting
#
#
# Review: mouth feels warm delicious never anything good type snack definitely going order getting jerky example superb cannot wait try
# Original summary: great hot beef sticks tasty not bland
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# Predicted summary:  great tasting
#
#
# Review: best marinade found long time use smoke baby back pork ribs really makes taste tried flavors garlic herb best try
# Original summary: love this stuff
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  great taste
#
#
# Review: toddler like took one gulp spit packaging cool great idea snap lid take go unfortunately kid would eat tried giving away luck ended trash
# Original summary: ella kitchen fruit smoothie the red one
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  great product for the price
#
#
# Review: organic price unbeatable good enough eat chia seeds feel good
# Original summary: chia seeds with unbeatable price
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  great product
#
#
# Review: great tasting tea hopefully amazon keep carrying found stores try one sure love
# Original summary: love this tea
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  great coffee
#
#
# Review: creamy thick formulation cleans styling products hair without stripping hair left feeling soft full smelling great big pantene fan great shampoo alternate need conditioner helps keep hair looking full flat
# Original summary: great and makes your hair look great
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  great product
#
#
# Review: find tasty product original non reduced fat still lot fat issue mine choose spend fat calories little non cholesterol margarine fry comes good hard find local stores
# Original summary: tasty way to reduce cholesterol
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# Predicted summary:  great taste
#
#
# Review: arrived fresh good shape like buying local store cheaper delivered door
# Original summary: great price
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  great taste
#
#
# Review: brownies awesome going try flavors asap even like low fat fat free stuff try brownies wonderful super easy hubby hates anything even looks low fat loved brownies happy eating
# Original summary: must try
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  great tasting
#
#
# Review: weather weightlifting fit staying healthy highly recommend product
# Original summary: great product
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  great product
#
#
# Review: unusual tasting mints ever also addicting flavor difficult describe define know need around time
# Original summary: howard violet mints
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great taste
#
#
# Review: every thing came thru ok except lid one bottle little lose bottle leaked shipping
# Original summary: fair
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# Predicted summary:  great product
#
#
# Review: received timely manner good condition mishka little spoiled cook meals afford buy wellness kibble ate willingly bought qualified overnight shipping unlike much heavier wellness bag almost kibble happy compromise
# Original summary: satisfactory
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# Predicted summary:  great product
#
#
# Review: loved orange slices since child hard find googled great treat found ordered hide orange slices packets indulge eat many bad thing
# Original summary: childhood treat still favorite
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# Predicted summary:  great product
#
#
# Review: cannot go wrong madhouse munchies sea salt vinegar favorite know chip amazing think wrong year old eating breakfast
# Original summary: yumm
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# Predicted summary:  great snack
#
#
# Review: tried cheese crackers supermarketland far best taste depth flavor great tangy cheddar cheese flavor keeps wanting trust disappointed try eat one serving amazon pricing subscribe program cannot beat
# Original summary: great tangy cheese flavor
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# Predicted summary:  great tasting
#
#
# Review: two boxers loved treat even put dab peanut butter center additional snack
# Original summary: yummy
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# Predicted summary:  great product
#
#
# Review: large chunks gave mill little bit hard time extra effort worth flavor superior slight bluish color lovely
# Original summary: very nice and pretty too
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# Predicted summary:  great product
#
#
# Review: bought creates awesome effect decorated cakes candies love completely edible wayyy overpriced amazon usually amazon cheaper buying stores craft store severely overpriced
# Original summary: great stuff too expensive on amazon
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great product
#
#
# Review: ordered box bags soy chips received opened bag chips darker color normal tasted one sour looked chips expired months ago option return bags waste
# Original summary: soy chips expired
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# Predicted summary:  great snack
#
#
# Review: thanks taking time make sure exactly needed product great look forward working future take care
# Original summary: great stuff
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# Predicted summary:  great product
#
#
# Review: like spicy like spicy enjoyed also crunchy kettle cooked chips
# Original summary: spicy but good
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  great tasting
#
#
# Review: switched totally himalayan salt several years ago health qualities paid lots retail stores price product great value salt also shakes easily salt container never clumping occur continue purchase future
# Original summary: great price for himalyan salt
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  great tasting
#
#
# Review: absolutely love actually shocked bunch one star reviews really nicely seasoned crunchy delicious want right
# Original summary: my absolute favorite walnuts
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# Predicted summary:  great tasting
#
#
# Review: pumpkin settle dogs stomach used able purchase walmart carry different brand found farmers market brand online excited almost buy reviews dented cans glad cans arrived perfectly
# Original summary: great
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# Predicted summary:  great product for dogs
#
#
# Review: british miss tea found amazon sold happy favorite tea good full flavor always consistantly good price right
# Original summary: pgtips
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# Predicted summary:  great coffee
#
#
# Review: really tastes like ginger honey drink hot cold like hot tea son likes cold hot inexpensive keep buying long sold love
# Original summary: this tastes so good
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  great tea
#
#
# Review: quite different grade maple syrups years brand favorite rich maple flavor nice thick texture love syrup buckwheat waffles pancakes highly recommended
# Original summary: excellent syrup
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  great product
#
#
# Review: cat miss princess like grass much grass purchased wal mart seeds grew nicely interested green stuff think purchase
# Original summary: cat did not like
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# Predicted summary:  great product for dogs
#
#
# Review: vet recommended help control tarted buildup dog absolutly loves almost think addicting gets one day makes sure forget give seemed help much rawhide chews keeping teeth clean
# Original summary: treats
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# Predicted summary:  great product for dogs
#
#
# Review: ice cream arrived fresh delicous kids adults loved little bricks icecream broken chunks seen even nasa gift shop thanks great product reasonable price hope inspires youngsters continue support space exploration
# Original summary: good stuff just as expected
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# Predicted summary:  great product
#
#
# Review: absolutely love nantucket blend bold yet weak either flavor great splash creamer door
# Original summary: yummy
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# Predicted summary:  great coffee
#
#
# Review: expert use anchovies occasionally perfect glass olive oil sit waiting patiently fridge used sauce dressing add right bit salt umami flavor
# Original summary: really nice anchovies
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# Predicted summary:  great product
#
#
# Review: bites beat living daylights jerky chewy bites perfect combination sweet salty perfect primal paleo friendly snack desk car gym bag
# Original summary: ridiculously delicious and primal friendly
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# Predicted summary:  great snack
#
#
# Review: trying first time little unsure huge fan almonds anything banana flavored boy glad tried really yummy perfect little pick snack school work taste even delicious warmed
# Original summary: healthy and yummy
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# Predicted summary:  great taste
#
#
# Review: second pack purchased large container seeds tasty probably buy
# Original summary: tasty sesame seeds
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# Predicted summary:  great product
#
#
# Review: one best breakfast bars ever tried soft sweet chewy wholesome oats nuts really stood love good eats good though sugar content bars little high still bought another box today
# Original summary: super tasty
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  great snack
#
#
# Review: ordered oz crab cakes usually expect shell every bite lump lump meat either great disappointment flavor fine would never order found crab cakes true lump much better
# Original summary: not good
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 19ms/step
# Predicted summary:  great product
#
#
# Review: bit perplexed wondering void beverage market intended fill imagine super sweet slightly carbonated juice drink almost syrupy consistency switch drink tall glass water drinking carbonated candy anything refreshing
# Original summary: too sweet and syrupy for my taste
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  great product
#
#
# Review: food great bag got amazon seemed stale half smashed powder get better pricess elsewhere
# Original summary: food but do not buy it here
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# Predicted summary:  great product
#
#
# Review: picked today thought would try since baby pretty good lot apple flavor nice texture enjoyed plan purchase use great snack
# Original summary: good for snack not just for baby
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# Predicted summary:  great taste
#
#
# Review: received case hoping add vegan menu made first batch could eat salty gave boxes owner local organic market
# Original summary: check sodium content before you purchase
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great product
#
#
# Review: local merchants quit stocking pleased buy line make french canadian pea soup stars ability obtain since quality much factor bob red mill products star
# Original summary: to be able to get this again
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# Predicted summary:  great product
#
#
# Review: second ingredient sugar need say make bisquit mix super easy
# Original summary: sugar sugar sugar
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great taste
#
#
# Review: favorite chip single serving bags help keep kids wasting good times grab something run keep couple bags car kids
# Original summary: taste fresh
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  great tasting snack
#
#
# Review: love bars healthy tasty filling worth every penny offer friends associates whenever ask healthy snack tastes great highly recommend
# Original summary: love it
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  great snack
#
#
# Review: nuts decent snack made cookies well slightly sweet think splenda taste overwhelming unpleasant obviously personal preference bought sale target package half current listed price
# Original summary: nice product but do not overpay
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  great snack
#
#
# Review: product dog absolute favorite comes dog treats find perfect training
# Original summary: zukes peanut butter mini treats
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  great product for dogs
#
#
# Review: shed stop makes big difference dogs coat look healthier shinier shed less great product
# Original summary: shed stop review
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# Predicted summary:  great product for dogs
#
#
# Review: switch people want drink one word explain drink straight great
# Original summary: switch black cherry
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 18ms/step
# Predicted summary:  great coffee
#
#
# Review: ok good meyenberg fresh goatmilk carton sort waters taste
# Original summary: goatmilkdrinker
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 46ms/step
# Predicted summary:  great taste
#
#
# Review: item came within appropriate time frame exactly expected shipping little spendy outrageous funny see come flat rate box though paying shipping
# Original summary: good buy
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 32ms/step
# Predicted summary:  great product
#
#
# Review: taste risotto awesome almost restaurant quality dinner party people asking made fresh tastes great
# Original summary: the very best packaged risotto
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 58ms/step
# Predicted summary:  great taste
#
#
# Review: glad read reviews coffee product cups fit keurig well make tasty cup coffee like fact plastic base less plastic trash buy favorite coffee thus far subscribed shipped automatically every month
# Original summary: great coffee great price
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 153ms/step
# Predicted summary:  great coffee
#
#
# Review: good sweet like fig newton type bars gritty like high fiber high protein bars eat afterschool snacks breakfast run
# Original summary: great taste
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  great tasting snack
#
#
# Review: add noodles veggies cooked wok soup spaghetti sauce makes low calorie dinner good anyone really watching weight enjoy others cannot use type substitute like
# Original summary: substitute noodles
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 26ms/step
# Predicted summary:  great tasting
#
#
# Review: quality purity appeared fine mild taste effective pleasant aroma used heavily know order comparison black peppercorn lampong
# Original summary: decent but extremely mild
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 81ms/step
# Predicted summary:  great coffee
#
#
# Review: opened bar harbor clam chowder could believe clams chowder mostly potatoes
# Original summary: bar harbor where are the clams
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  great tasting
#
#
# Review: brews wonderful pot tea great hot also delicious cold ginger adds hint zing slightly sweet black tea drinking lot
# Original summary: full bodied fruity black tea with zing
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 29ms/step
# Predicted summary:  great coffee
#
#
# Review: looking organic black tea replace tetley tea usually drink stash tea wish less expensive feel worth
# Original summary: tea time
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 50ms/step
# Predicted summary:  great coffee
#
#
# Review: absolutely love flavors tea husband drink anything else
# Original summary: herbal unwind tea
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 49ms/step
# Predicted summary:  great coffee
#
#
# Review: super fast shipping even included couple trial treats dog loves purchasing
# Original summary: our dog loves her greenies
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 32ms/step
# Predicted summary:  great product
#
#
# Review: want try something different exotic refreshing tea many benefits body box arrived intact
# Original summary: great product
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 18ms/step
# Predicted summary:  great tea
#
#
# Review: powerful drink mix powerfull energy levels right drinking taste amazing recommend anyone wants energy boost hours
# Original summary: excellent powdered drink mix
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# Predicted summary:  great product
#
#
# Review: mixed water create paste put celery good substitute regular peanut butter love getting nutty taste without fat calories
# Original summary: impressed so far
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  great taste
#
#
# Review: big fan dried mangos costco except much sugar coating wanted try well ok mango pieces small
# Original summary: they were just ok
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  great product
#
#
# Review: like oil much fruity lots flavor eaten oil varieties chile also taste good olive varietals soil good taste repeat customer
# Original summary: very good oil indeed
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  great product
#
#
# Review: natural superfoods surprise got make feel fuller longer also natural thickener hummus looked bit runny added chia thickened really well
# Original summary: makes you feel full and natural thickener
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# Predicted summary:  great product
#
#
# Review: bear creek soup mixes great add meat complete hearty meal small amount time jabc
# Original summary: good quick foods
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great tasting
#
#
# Review: ramen ok think ever going use flavor packets eat noodles pick different flavor ramen recommend creamy chicken quite delicious
# Original summary: edible but weird
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# Predicted summary:  great taste
#
#
# Review: freshness problem order however problem chocolate fudge stripes melted cookies stuck inside package another go repeat sales
# Original summary: chocolate all melted
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# Predicted summary:  great taste
#
#
# Review: miss pitty loves favors thanks making yummy daily meal girl description says oz packages expecting paper type packaging little disappointed food came cans
# Original summary: excellent but not package
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great product
#
#
# Review: disappointed unable find delicious chicken helper local stores anymore happy find could ordered amazon would take use boxes though gave children enjoy also thanks amazon making available
# Original summary: good food
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  great taste
#
#
# Review: dogs hard please food eat almost anything little interest cases stuff bought maybe add something like salt
# Original summary: dogs do not like it
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  great product for dogs
#
#
# Review: love tea helps hunger pains metabolism would recommend everyone thank
# Original summary: tea
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# Predicted summary:  great coffee
#
#
# Review: think need milder though love mint taste
# Original summary: great item for summer
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  great product
#
#
# Review: best cup flavored coffee book strong multi layered flavor perfect wake call delivery time java jived happy customer
# Original summary: best product of it is kind
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  great coffee
#
#
# Review: bought almonds twice packs timese horrible small stale packs embarrassed serve friends would recommend
# Original summary: stale each time
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great product
#
#
# Review: sure think great flavorful blue diamond almonds however good make fine snack even trade good great eating almonds better bought kroger
# Original summary: good but not quite great
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# Predicted summary:  great taste
#
#
# Review: dogs go crazy liver biscottis nice crunchy helps clean teeth ingredients wholesome
# Original summary: my dogs love em
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# Predicted summary:  great product for dogs
#
#
# Review: expecting pictured gift packaging good price sea salt hoping would come shown illustration naive would nice little hostess gift shown illustration
# Original summary: where is the gift packaging
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# Predicted summary:  great product
#
#
# Review: smell fresh hoped cat uninterested trader joe organic catnip comes scratcher smells much potent maybe try different brand
# Original summary: eh
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 35ms/step
# Predicted summary:  great product for dogs
#
#
# Review: better expected well packaged moist fresh fragrant beans needed recipe perfect would hesitate order bargain priced excellent product
# Original summary: vanilla beans
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great product
#
#
# Review: big time coffee drinker tend like coffee strong tully french roast blend delivers going go details taste like everybody taste different like strong bitter cup coffee get going morning
# Original summary: luv this coffee
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great coffee
#
#
# Review: chili pepper spices olive nicely hot scale pepper stuffed olive probably hotness good product
# Original summary: hot but not too hot
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# Predicted summary:  great taste
#
#
# Review: bought girlfriend loves product shipped fast well well packaged
# Original summary: nice product
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  great product
#
#
# Review: product absolute must try substitute sugar baking desserts love low glycemic index
# Original summary: excellent product
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# Predicted summary:  great taste
#
#
# Review: got tablets try see really worked suprise made lemons taste amazing items list taste much better still trying
# Original summary: lemons are amazing
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# Predicted summary:  great product
#
#
# Review: excellent product teeth get online half price vet
# Original summary: cet
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 18ms/step
# Predicted summary:  great product for dogs
#
#
# Review: fresher chestnut taste others tried people looking healthy snack chestnuts probably closer brown rice nuts pretty low fat would recommend
# Original summary: taste great and healthy
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  great taste
